# %%
# Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_regression, mutual_info_classif
from sklearn.preprocessing import LabelEncoder
import os

# %%
os.chdir(r"C:\Users\tandu\iCloudDrive\Research\Data\Phenotype")

# %%
dataset = pd.read_csv('Maize_allphospho(1).csv')
dataset = dataset.drop(dataset.columns[0], axis=1)
dataset.head
# Out:
# <bound method NDFrame.head of        sol  sol_Hi  sol_Lo  sol_Mo  sol_VL         tot        lab         org  \
# 0      8.0       0       0     100       0  272.378723  19.742783   67.555527
# 1      9.0       0      30      70       0  321.889160  39.771477  130.869049
# 2      9.0       0      30      70       0  297.140411  15.604735   55.663460
# 3      8.0       0       0     100       0  272.378723  19.742783   67.555527
# 4      9.0       0      30      70       0  272.378723  14.778452   33.163631
# ...    ...     ...     ...     ...     ...         ...        ...         ...
# 3534  12.0       0     100       0       0  184.489365   9.688712   34.560482
# 3535  12.0       0     100       0       0  184.489365   9.688712   34.560482
# 3536   9.0       0      40      60       0  184.489365   9.688712   34.560482
# 3537   8.0       0       0     100       0  184.489365   9.688712   34.560482
# 3538  11.0       0      60      40       0  297.140411  21.537582   73.696930
#
#              occ        sec  ...   PHO2   PMEH1  PMEH2    PNZ1    PNZ2   POL1  \
# 0     102.826088  30.978016  ...    NaN   719.0  230.0  4727.0  5387.0  650.0
# 1      73.313477  23.083660  ...    NaN     NaN    NaN  3072.0  4551.0    NaN
# 2     130.878677  13.038733  ...  800.0  2521.0  306.0  2258.0  2507.0  766.0
# 3     102.826088  30.978016  ...    NaN  1217.0  327.0  4256.0  4311.0  634.0
# 4     128.609207  16.709021  ...    NaN  1293.0  538.0  2822.0  2659.0  906.0
# ...          ...        ...  ...    ...     ...    ...     ...     ...    ...
# 3534   81.260315   8.095524  ...    NaN  1665.0  291.0  3768.0  3879.0  526.0
# 3535   81.260315   8.095524  ...    NaN  1665.0  291.0  3768.0  3879.0  526.0
# 3536   81.260315   8.095524  ...    NaN     NaN    NaN     NaN     NaN    NaN
# 3537   81.260315   8.095524  ...  800.0  2257.0  441.0  1430.0  1775.0  830.0
# 3538  112.173912  33.794197  ...  600.0   120.0    0.0  5251.0  6522.0  524.0
#
#        POL2    TP1    TP2    NPlim
# 0     199.0  700.0  600.0      NaN
# 1       NaN    NaN    NaN -0.47906
# 2     129.0  500.0  400.0 -0.46164
# 3       NaN  600.0  600.0      NaN
# 4       NaN  600.0  400.0      NaN
# ...     ...    ...    ...      ...
# 3534   92.0  600.0  400.0      NaN
# 3535   92.0  600.0  400.0      NaN
# 3536    NaN    NaN    NaN      NaN
# 3537  113.0  500.0  400.0 -0.40519
# 3538  182.0  900.0  700.0 -0.27124
#
# [3539 rows x 28 columns]>

# %%
# Info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3539 entries, 0 to 3538
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sol     3502 non-null   float64
#  1   sol_Hi  3539 non-null   int64
#  2   sol_Lo  3539 non-null   int64
#  3   sol_Mo  3539 non-null   int64
#  4   sol_VL  3539 non-null   int64
#  5   tot     2561 non-null   float64
#  6   lab     2561 non-null   float64
#  7   org     2561 non-null   float64
#  8   occ     2561 non-null   float64
#  9   sec     2561 non-null   float64
#  10  apa     2561 non-null   float64
#  11  stp10   3468 non-null   float64
#  12  stp100  3468 non-null   float64
#  13  stp20   3468 non-null   float64
#  14  stp30   3468 non-null   float64
#  15  PBR1    3217 non-null   float64
#  16  PBR2    3044 non-null   float64
#  17  PHO1    1097 non-null   float64
#  18  PHO2    891 non-null    float64
#  19  PMEH1   1627 non-null   float64
#  20  PMEH2   1627 non-null   float64
#  21  PNZ1    3217 non-null   float64
#  22  PNZ2    3217 non-null   float64
#  23  POL1    1434 non-null   float64
#  24  POL2    921 non-null    float64
#  25  TP1     3042 non-null   float64
#  26  TP2     3042 non-null   float64
#  27  NPlim   1645 non-null   float64
# dtypes: float64(24), int64(4)
# memory usage: 774.3 KB

# %%
maize_pca = pd.read_csv("maize_covariates.csv")
maize_pca_second_column = maize_pca.iloc[:, 1]
#maize_pca = maize_pca[['EV1']]
maize_pca_second_column
# Out:
# 0      -0.015897
# 1      -0.009884
# 2      -0.009309
# 3      -0.010773
# 4      -0.015116
#           ...
# 3534   -0.009823
# 3535   -0.010400
# 3536   -0.009009
# 3537   -0.014760
# 3538   -0.018210
# Name: EV1, Length: 3539, dtype: float64

# %%
dataset = pd.concat([maize_pca_second_column, dataset], axis=1)
print(dataset)
dataset.info()
# Out:
#            EV1   sol  sol_Hi  sol_Lo  sol_Mo  sol_VL         tot        lab  \
# 0    -0.015897   8.0       0       0     100       0  272.378723  19.742783
# 1    -0.009884   9.0       0      30      70       0  321.889160  39.771477
# 2    -0.009309   9.0       0      30      70       0  297.140411  15.604735
# 3    -0.010773   8.0       0       0     100       0  272.378723  19.742783
# 4    -0.015116   9.0       0      30      70       0  272.378723  14.778452
# ...        ...   ...     ...     ...     ...     ...         ...        ...
# 3534 -0.009823  12.0       0     100       0       0  184.489365   9.688712
# 3535 -0.010400  12.0       0     100       0       0  184.489365   9.688712
# 3536 -0.009009   9.0       0      40      60       0  184.489365   9.688712
# 3537 -0.014760   8.0       0       0     100       0  184.489365   9.688712
# 3538 -0.018210  11.0       0      60      40       0  297.140411  21.537582
#
#              org         occ  ...   PHO2   PMEH1  PMEH2    PNZ1    PNZ2  \
# 0      67.555527  102.826088  ...    NaN   719.0  230.0  4727.0  5387.0
# 1     130.869049   73.313477  ...    NaN     NaN    NaN  3072.0  4551.0
# 2      55.663460  130.878677  ...  800.0  2521.0  306.0  2258.0  2507.0
# 3      67.555527  102.826088  ...    NaN  1217.0  327.0  4256.0  4311.0
# 4      33.163631  128.609207  ...    NaN  1293.0  538.0  2822.0  2659.0
# ...          ...         ...  ...    ...     ...    ...     ...     ...
# 3534   34.560482   81.260315  ...    NaN  1665.0  291.0  3768.0  3879.0
# 3535   34.560482   81.260315  ...    NaN  1665.0  291.0  3768.0  3879.0
# 3536   34.560482   81.260315  ...    NaN     NaN    NaN     NaN     NaN
# 3537   34.560482   81.260315  ...  800.0  2257.0  441.0  1430.0  1775.0
# 3538   73.696930  112.173912  ...  600.0   120.0    0.0  5251.0  6522.0
#
#        POL1   POL2    TP1    TP2    NPlim
# 0     650.0  199.0  700.0  600.0      NaN
# 1       NaN    NaN    NaN    NaN -0.47906
# 2     766.0  129.0  500.0  400.0 -0.46164
# 3     634.0    NaN  600.0  600.0      NaN
# 4     906.0    NaN  600.0  400.0      NaN
# ...     ...    ...    ...    ...      ...
# 3534  526.0   92.0  600.0  400.0      NaN
# 3535  526.0   92.0  600.0  400.0      NaN
# 3536    NaN    NaN    NaN    NaN      NaN
# 3537  830.0  113.0  500.0  400.0 -0.40519
# 3538  524.0  182.0  900.0  700.0 -0.27124
#
# [3539 rows x 29 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3539 entries, 0 to 3538
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   EV1     3539 non-null   float64
#  1   sol     3502 non-null   float64
#  2   sol_Hi  3539 non-null   int64
#  3   sol_Lo  3539 non-null   int64
#  4   sol_Mo  3539 non-null   int64
#  5   sol_VL  3539 non-null   int64
#  6   tot     2561 non-null   float64
#  7   lab     2561 non-null   float64
#  8   org     2561 non-null   float64
#  9   occ     2561 non-null   float64
#  10  sec     2561 non-null   float64
#  11  apa     2561 non-null   float64
#  12  stp10   3468 non-null   float64
#  13  stp100  3468 non-null   float64
#  14  stp20   3468 non-null   float64
#  15  stp30   3468 non-null   float64
#  16  PBR1    3217 non-null   float64
#  17  PBR2    3044 non-null   float64
#  18  PHO1    1097 non-null   float64
#  19  PHO2    891 non-null    float64
#  20  PMEH1   1627 non-null   float64
#  21  PMEH2   1627 non-null   float64
#  22  PNZ1    3217 non-null   float64
#  23  PNZ2    3217 non-null   float64
#  24  POL1    1434 non-null   float64
#  25  POL2    921 non-null    float64
#  26  TP1     3042 non-null   float64
#  27  TP2     3042 non-null   float64
#  28  NPlim   1645 non-null   float64
# dtypes: float64(25), int64(4)
# memory usage: 801.9 KB

# %%
# Checking the presence of categorical features
dataset.describe(include='O')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17780\598984503.py in <module>
#       1 # Checking the presence of categorical features
# ----> 2 dataset.describe(include='O')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10230         max            NaN      3.0
#   10231         """
# > 10232         return describe_ndframe(
#   10233             obj=self,
#   10234             include=include,
#
# ~\anaconda3\lib\site-packages\pandas\core\describe.py in describe_ndframe(obj, include, exclude, datetime_is_numeric, percentiles)
#      92         )
#      93
# ---> 94     result = describer.describe(percentiles=percentiles)
#      95     return cast(NDFrameT, result)
#      96
#
# ~\anaconda3\lib\site-packages\pandas\core\describe.py in describe(self, percentiles)
#     175
#     176         col_names = reorder_columns(ldesc)
# --> 177         d = concat(
#     178             [x.reindex(col_names, copy=False) for x in ldesc],
#     179             axis=1,
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     402
#     403         if len(objs) == 0:
# --> 404             raise ValueError("No objects to concatenate")
#     405
#     406         if keys is None:
#
# ValueError: No objects to concatenate

# %%
#Creating the input features X and target variable y
X= dataset.iloc[:,1:28]
y= dataset.iloc[:,0].values

# %%
# Create a data set with all the input features after converting them to numeric including target variable
full_data= X.copy()
full_data['EV1']= y
full_data.head(8)
# Out:
#    sol  sol_Hi  sol_Lo  sol_Mo  sol_VL         tot        lab         org  \
# 0  8.0       0       0     100       0  272.378723  19.742783   67.555527
# 1  9.0       0      30      70       0  321.889160  39.771477  130.869049
# 2  9.0       0      30      70       0  297.140411  15.604735   55.663460
# 3  8.0       0       0     100       0  272.378723  19.742783   67.555527
# 4  9.0       0      30      70       0  272.378723  14.778452   33.163631
# 5  9.0      10       0      70      20  532.376648  45.548256   25.685507
# 6  9.0      10      20      50      20  545.812012  58.875229   83.113129
# 7  8.0       0       0     100       0  321.889160  39.771477  130.869049
#
#           occ        sec  ...    PHO2   PMEH1  PMEH2    PNZ1    PNZ2   POL1  \
# 0  102.826088  30.978016  ...     NaN   719.0  230.0  4727.0  5387.0  650.0
# 1   73.313477  23.083660  ...     NaN     NaN    NaN  3072.0  4551.0    NaN
# 2  130.878677  13.038733  ...   800.0  2521.0  306.0  2258.0  2507.0  766.0
# 3  102.826088  30.978016  ...     NaN  1217.0  327.0  4256.0  4311.0  634.0
# 4  128.609207  16.709021  ...     NaN  1293.0  538.0  2822.0  2659.0  906.0
# 5   91.970459  30.454041  ...     NaN     NaN    NaN  2902.0  3359.0    NaN
# 6  117.754028  28.803104  ...    25.0  1983.0  172.0  3792.0  3786.0    NaN
# 7   73.313477  23.083660  ...  1200.0  2976.0  288.0  1741.0  2028.0  871.0
#
#     POL2    TP1    TP2       EV1
# 0  199.0  700.0  600.0 -0.015897
# 1    NaN    NaN    NaN -0.009884
# 2  129.0  500.0  400.0 -0.009309
# 3    NaN  600.0  600.0 -0.010773
# 4    NaN  600.0  400.0 -0.015116
# 5    NaN  400.0  300.0 -0.018069
# 6    NaN  700.0  400.0 -0.016920
# 7  153.0  500.0  400.0 -0.014964
#
# [8 rows x 28 columns]

# %%
# Applying step 1 of the filter method
# Identify input features having high correlation with target variable

importances = full_data.drop("EV1", axis=1).apply(lambda x: x.corr(full_data.EV1))
indices = np.argsort(importances)
print(importances[indices])
# Out:
# sol_Hi   -0.294381
# sol      -0.106655
# POL2     -0.103776
# PMEH2     0.000886
# sol_Lo    0.001234
# sol_Mo    0.066007
# POL1      0.085760
# PNZ1      0.093505
# PBR2      0.100178
# PBR1      0.139993
# sol_VL    0.144000
# PNZ2      0.156046
# org       0.199076
# PMEH1     0.234201
# sec       0.249960
# lab       0.291087
# occ       0.385651
# tot       0.391909
# stp10     0.412784
# apa       0.415450
# TP1       0.420241
# stp100    0.421499
# stp30     0.426044
# stp20     0.442227
# PHO1      0.464630
# TP2       0.526864
# PHO2      0.541163
# dtype: float64

# %%
#Plotting 
exclude = ['EV1']
names = [col for col in dataset.columns if col not in exclude]
#print(columns_keep)
#names=['sol_Hi','sol','POL2','PMEH2','POL1','sol_Lo','sol_Mo','PNZ1','PBR1','PBR2','PMEH1','sol_VL',]
plt.title('Most Variance')
plt.barh(range(len(indices)), importances[indices], color='g', align='center')
plt.yticks(range(len(indices)), [names[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
# We want to keep features with only a high correlation with the target variable. This implies that the input feature has a high influence in predicting the target variable.
# We set the threshold to the absolute value of 0.3. We keep input features only if the correlation of the input feature with the target variable is greater than 0.4

for i in range(0, len(indices)):
    if np.abs(importances[i])>=0.2:
        print(names[i])
# Out:
# sol_Hi
# tot
# lab
# occ
# sec
# apa
# stp10
# stp100
# stp20
# stp30
# PHO1
# PHO2
# PMEH1
# TP1
# TP2

# %%
X = dataset[['sol_Hi','tot','lab','sec','apa','stp10','stp100','stp20','stp30','PHO1','PHO2','PMEH1','TP1','TP2']]

# %%
# Step 2 of the filter method
#Identify input features that have a low correlation with other independent variables.
#Iterating through all the filtered input features based on step 1 and checking each input feature correlation with all other input features.
#We will keep input features that are not highly correlated with other input features

for i in range(0,len(X.columns)):
    for j in  range(0,len(X.columns)):
        if i!=j:
            corr_1=np.abs(X[X.columns[i]].corr(X[X.columns[j]]))
            if corr_1 <0.3:
                print( X.columns[i] , " is not correlated  with ", X.columns[j])
            elif corr_1>0.75:
                print( X.columns[i] , " is highly  correlated  with ", X.columns[j])
# Out:
# sol_Hi  is not correlated  with  tot
# sol_Hi  is not correlated  with  lab
# sol_Hi  is not correlated  with  sec
# sol_Hi  is not correlated  with  apa
# sol_Hi  is not correlated  with  stp10
# sol_Hi  is not correlated  with  stp100
# sol_Hi  is not correlated  with  stp20
# sol_Hi  is not correlated  with  stp30
# sol_Hi  is not correlated  with  PHO1
# sol_Hi  is not correlated  with  PMEH1
# sol_Hi  is not correlated  with  TP1
# sol_Hi  is not correlated  with  TP2
# tot  is not correlated  with  sol_Hi
# tot  is highly  correlated  with  lab
# tot  is highly  correlated  with  sec
# tot  is highly  correlated  with  apa
# tot  is not correlated  with  PHO1
# tot  is not correlated  with  PHO2
# tot  is not correlated  with  PMEH1
# tot  is not correlated  with  TP2
# lab  is not correlated  with  sol_Hi
# lab  is highly  correlated  with  tot
# lab  is highly  correlated  with  sec
# lab  is not correlated  with  PHO1
# lab  is not correlated  with  PHO2
# lab  is not correlated  with  PMEH1
# lab  is not correlated  with  TP2
# sec  is not correlated  with  sol_Hi
# sec  is highly  correlated  with  tot
# sec  is highly  correlated  with  lab
# sec  is not correlated  with  PHO1
# sec  is not correlated  with  PHO2
# sec  is not correlated  with  TP1
# sec  is not correlated  with  TP2
# apa  is not correlated  with  sol_Hi
# apa  is highly  correlated  with  tot
# apa  is not correlated  with  stp10
# apa  is not correlated  with  stp100
# apa  is not correlated  with  stp20
# apa  is not correlated  with  stp30
# apa  is not correlated  with  PHO1
# apa  is not correlated  with  PMEH1
# stp10  is not correlated  with  sol_Hi
# stp10  is not correlated  with  apa
# stp10  is highly  correlated  with  stp100
# stp10  is highly  correlated  with  stp20
# stp10  is highly  correlated  with  stp30
# stp10  is not correlated  with  PHO1
# stp10  is not correlated  with  PHO2
# stp10  is not correlated  with  PMEH1
# stp100  is not correlated  with  sol_Hi
# stp100  is not correlated  with  apa
# stp100  is highly  correlated  with  stp10
# stp100  is highly  correlated  with  stp20
# stp100  is highly  correlated  with  stp30
# stp100  is not correlated  with  PHO1
# stp100  is not correlated  with  PHO2
# stp100  is not correlated  with  PMEH1
# stp20  is not correlated  with  sol_Hi
# stp20  is not correlated  with  apa
# stp20  is highly  correlated  with  stp10
# stp20  is highly  correlated  with  stp100
# stp20  is highly  correlated  with  stp30
# stp20  is not correlated  with  PHO1
# stp20  is not correlated  with  PHO2
# stp20  is not correlated  with  PMEH1
# stp30  is not correlated  with  sol_Hi
# stp30  is not correlated  with  apa
# stp30  is highly  correlated  with  stp10
# stp30  is highly  correlated  with  stp100
# stp30  is highly  correlated  with  stp20
# stp30  is not correlated  with  PHO1
# stp30  is not correlated  with  PHO2
# stp30  is not correlated  with  PMEH1
# PHO1  is not correlated  with  sol_Hi
# PHO1  is not correlated  with  tot
# PHO1  is not correlated  with  lab
# PHO1  is not correlated  with  sec
# PHO1  is not correlated  with  apa
# PHO1  is not correlated  with  stp10
# PHO1  is not correlated  with  stp100
# PHO1  is not correlated  with  stp20
# PHO1  is not correlated  with  stp30
# PHO1  is highly  correlated  with  PHO2
# PHO1  is highly  correlated  with  PMEH1
# PHO1  is not correlated  with  TP2
# PHO2  is not correlated  with  tot
# PHO2  is not correlated  with  lab
# PHO2  is not correlated  with  sec
# PHO2  is not correlated  with  stp10
# PHO2  is not correlated  with  stp100
# PHO2  is not correlated  with  stp20
# PHO2  is not correlated  with  stp30
# PHO2  is highly  correlated  with  PHO1
# PHO2  is not correlated  with  TP1
# PHO2  is not correlated  with  TP2
# PMEH1  is not correlated  with  sol_Hi
# PMEH1  is not correlated  with  tot
# PMEH1  is not correlated  with  lab
# PMEH1  is not correlated  with  apa
# PMEH1  is not correlated  with  stp10
# PMEH1  is not correlated  with  stp100
# PMEH1  is not correlated  with  stp20
# PMEH1  is not correlated  with  stp30
# PMEH1  is highly  correlated  with  PHO1
# PMEH1  is not correlated  with  TP2
# TP1  is not correlated  with  sol_Hi
# TP1  is not correlated  with  sec
# TP1  is not correlated  with  PHO2
# TP2  is not correlated  with  sol_Hi
# TP2  is not correlated  with  tot
# TP2  is not correlated  with  lab
# TP2  is not correlated  with  sec
# TP2  is not correlated  with  PHO1
# TP2  is not correlated  with  PHO2
# TP2  is not correlated  with  PMEH1

# %%
#Based on the above result we keep non correlated 
X= dataset[['apa','stp10','PHO1','TP1']]

# %%
#Apply step 3 of the filter method
# Find the information gain or mutual information of the independent variable with respect to a target variable
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
X = imputer.fit_transform(X)
mi = mutual_info_regression(X, y)

# %%
#Plotting the mutual information
import pandas as pd
X_np = X.values
mi = mutual_info_regression(X_np, y)
mi = pd.Series(mi)
mi.index = X.columns
mi.sort_values(ascending=False, inplace=True)
mi.sort_values(ascending=False).plot.bar(figsize=(10, 4))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12152\2872970375.py in <module>
#       1 #Plotting the mutual information
#       2 import pandas as pd
# ----> 3 X_np = X.values
#       4 mi = mutual_info_regression(X_np, y)
#       5 mi = pd.Series(mi)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
#using the SelectKBest class from the sklearn.feature_selection module
from sklearn.feature_selection import SelectKBest,  f_classif , f_regression, mutual_info_classif, mutual_info_regression, chi2, SelectPercentile, SelectFpr, SelectFdr, SelectFwe, GenericUnivariateSelect
from sklearn.feature_selection import chi2

# %%
# X is a matrix of feature values and y is a vector of target values
x_feature = dataset.iloc[::,1:28]
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
x_feature = imputer.fit_transform(x_feature)
#x_feature = x_feature.to_numpy()

y_target = dataset[['EV1']]
y_target = y_target.values
print(x_feature)
print(y_target)
print(np.isinf(x_feature).any())
# Out:
# [[  8.           0.           0.         ... 199.         700.
#   600.        ]
#  [  9.           0.          30.         ... 153.54614549 631.06508876
#   515.84483892]
#  [  9.           0.          30.         ... 129.         500.
#   400.        ]
#  ...
#  [  9.           0.          40.         ... 153.54614549 631.06508876
#   515.84483892]
#  [  8.           0.           0.         ... 113.         500.
#   400.        ]
#  [ 11.           0.          60.         ... 182.         900.
#   700.        ]]
# [[-0.01589676]
#  [-0.00988401]
#  [-0.00930928]
#  ...
#  [-0.00900873]
#  [-0.01475961]
#  [-0.01820967]]
# False

# %%
#Select the top 10 features using chi-square test
selector = SelectKBest(score_func = chi2, k = 10)

#x_feature_new = selector.fit_transform(x_feature, y_target)
fit = selector.fit(x_feature, y_target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12152\2862280092.py in <module>
#       3
#       4 #x_feature_new = selector.fit_transform(x_feature, y_target)
# ----> 5 fit = selector.fit(x_feature, y_target)
#
# ~\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     406
#     407         self._check_params(X, y)
# --> 408         score_func_ret = self.score_func(X, y)
#     409         if isinstance(score_func_ret, (list, tuple)):
#     410             self.scores_, self.pvalues_ = score_func_ret
#
# ~\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in chi2(X, y)
#     215         raise ValueError("Input X must be non-negative.")
#     216
# --> 217     Y = LabelBinarizer().fit_transform(y)
#     218     if Y.shape[1] == 1:
#     219         Y = np.append(1 - Y, Y, axis=1)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in fit_transform(self, y)
#     322             will be of CSR format.
#     323         """
# --> 324         return self.fit(y).transform(y)
#     325
#     326     def transform(self, y):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in fit(self, y)
#     299
#     300         self.sparse_input_ = sp.issparse(y)
# --> 301         self.classes_ = unique_labels(y)
#     302         return self
#     303
#
# ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py in unique_labels(*ys)
#      99     _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#     100     if not _unique_labels:
# --> 101         raise ValueError("Unknown label type: %s" % repr(ys))
#     102
#     103     ys_labels = set(chain.from_iterable(_unique_labels(y) for y in ys))
#
# ValueError: Unknown label type: (array([[-0.01589676],
#        [-0.00988401],
#        [-0.00930928],
#        ...,
#        [-0.00900873],
#        [-0.01475961],
#        [-0.01820967]]),)

# %%
#Select the top 10 features using F test
x_feature_original = x_feature
x_feature_original = pd.DataFrame(x_feature_original)

selector = SelectKBest(score_func = f_regression, k = 10)


x_feature_new = selector.fit_transform(x_feature, y_target.ravel())
print(x_feature_new)
selected_feature_names = x_feature_original.columns[selector.get_support()]

#selected_columns = dataset.iloc[:, selected_feature_names]
print("column number first is zero", selected_feature_names)
#print(dataset)
#selected_columns

selected_feature_names = selected_feature_names + 1
selected_columns = dataset.iloc[:, selected_feature_names]
selected_columns
print("after",selected_columns)
# Out:
# [[   0.          272.37872314  102.82608795 ...  761.79559326
#    700.          600.        ]
#  [   0.          321.88916016   73.31347656 ...  999.77081299
#    631.06508876  515.84483892]
#  [   0.          297.14041138  130.87867737 ... 1074.6730957
#    500.          400.        ]
#  ...
#  [   0.          184.48936462   81.26031494 ...  504.95513916
#    631.06508876  515.84483892]
#  [   0.          184.48936462   81.26031494 ...  352.74462891
#    500.          400.        ]
#  [   0.          297.14041138  112.17391205 ...  385.38134766
#    900.          700.        ]]
# column number first is zero Int64Index([1, 5, 8, 10, 11, 12, 13, 14, 25, 26], dtype='int64')
# after       sol_Hi         tot         occ        apa        stp10       stp100  \
# 0          0  272.378723  102.826088  51.276287   794.583374   717.886108
# 1          0  321.889160   73.313477  54.851479  1138.536743   981.948181
# 2          0  297.140411  130.878677  81.954819  1196.093994  1057.599731
# 3          0  272.378723  102.826088  51.276287   907.798584   800.458557
# 4          0  272.378723  128.609207  79.118378   514.703247   456.280579
# ...      ...         ...         ...        ...          ...          ...
# 3534       0  184.489365   81.260315  50.884335   563.654297   433.089447
# 3535       0  184.489365   81.260315  50.884335   688.251099   460.656067
# 3536       0  184.489365   81.260315  50.884335   656.158447   488.976532
# 3537       0  184.489365   81.260315  50.884335   382.251740   352.409973
# 3538       0  297.140411  112.173912  55.937767   376.669250   363.388153
#
#             stp20        stp30    TP1    TP2
# 0      795.179993   761.795593  700.0  600.0
# 1     1075.211548   999.770813    NaN    NaN
# 2     1163.314453  1074.673096  500.0  400.0
# 3      843.005554   817.252258  600.0  600.0
# 4      481.724823   470.720886  600.0  400.0
# ...           ...          ...    ...    ...
# 3534   493.885742   456.354004  600.0  400.0
# 3535   531.773865   488.279114  600.0  400.0
# 3536   551.613098   504.955139    NaN    NaN
# 3537   353.554871   352.744629  500.0  400.0
# 3538   387.483398   385.381348  900.0  700.0
#
# [3539 rows x 10 columns]

# %%
#Select the top 10 features using F test
x_feature_original = x_feature
x_feature_original = pd.DataFrame(x_feature_original)

selector = SelectKBest(score_func = mutual_info_regression, k = 10)


x_feature_new = selector.fit_transform(x_feature, y_target.ravel())
print(x_feature_new)
selected_feature_names = x_feature_original.columns[selector.get_support()]

#selected_columns = dataset.iloc[:, selected_feature_names]
print("column number first is zero", selected_feature_names)
#print(dataset)
#selected_columns

selected_feature_names = selected_feature_names + 1
selected_columns = dataset.iloc[:, selected_feature_names]
selected_columns
print("after",selected_columns)
# Out:
# [[  30.9780159    51.27628708  794.58337402 ...   28.
#   4727.         5387.        ]
#  [  23.08366013   54.85147858 1138.53674316 ...  211.02332457
#   3072.         4551.        ]
#  [  13.03873348   81.95481873 1196.09399414 ...  181.
#   2258.         2507.        ]
#  ...
#  [   8.09552383   50.88433456  656.15844727 ...  211.02332457
#   3742.08361828 4459.99347218]
#  [   8.09552383   50.88433456  382.2517395  ...  490.
#   1430.         1775.        ]
#  [  33.79419708   55.93776703  376.66925049 ...   47.
#   5251.         6522.        ]]
# column number first is zero Int64Index([9, 10, 11, 12, 13, 14, 15, 16, 21, 22], dtype='int64')
# after             sec        apa        stp10       stp100        stp20  \
# 0     30.978016  51.276287   794.583374   717.886108   795.179993
# 1     23.083660  54.851479  1138.536743   981.948181  1075.211548
# 2     13.038733  81.954819  1196.093994  1057.599731  1163.314453
# 3     30.978016  51.276287   907.798584   800.458557   843.005554
# 4     16.709021  79.118378   514.703247   456.280579   481.724823
# ...         ...        ...          ...          ...          ...
# 3534   8.095524  50.884335   563.654297   433.089447   493.885742
# 3535   8.095524  50.884335   688.251099   460.656067   531.773865
# 3536   8.095524  50.884335   656.158447   488.976532   551.613098
# 3537   8.095524  50.884335   382.251740   352.409973   353.554871
# 3538  33.794197  55.937767   376.669250   363.388153   387.483398
#
#             stp30    PBR1   PBR2    PNZ1    PNZ2
# 0      761.795593   289.0   28.0  4727.0  5387.0
# 1      999.770813  1731.0    NaN  3072.0  4551.0
# 2     1074.673096  1817.0  181.0  2258.0  2507.0
# 3      817.252258   533.0   14.0  4256.0  4311.0
# 4      470.720886   797.0   65.0  2822.0  2659.0
# ...           ...     ...    ...     ...     ...
# 3534   456.354004  3028.0  163.0  3768.0  3879.0
# 3535   488.279114  3028.0  163.0  3768.0  3879.0
# 3536   504.955139     NaN    NaN     NaN     NaN
# 3537   352.744629  2563.0  490.0  1430.0  1775.0
# 3538   385.381348   261.0   47.0  5251.0  6522.0
#
# [3539 rows x 10 columns]

# %%
# import necessary libraries
from ReliefF import ReliefF
import numpy as np
from sklearn import datasets
import pandas as pd

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
X = imputer.fit_transform(X)

# %%
fs = ReliefF(n_neighbors=1, n_features_to_keep=15)

# %%
X_train = fs.fit_transform(X, y)

# %%
print(X_train)
print("--------------")
print("(No. of tuples, No. of Columns before ReliefF) : "+str(X.shape)+
      "\n(No. of tuples , No. of Columns after ReliefF) : "+str(X_train.shape))
# Out:
# [[ 795.17999268  761.79559326  794.58337402 ...    8.
#      0.          289.        ]
#  [1075.21154785  999.77081299 1138.53674316 ...    9.
#      0.         1731.        ]
#  [1163.31445312 1074.6730957  1196.09399414 ...    9.
#      0.         1817.        ]
#  ...
#  [ 551.61309814  504.95513916  656.15844727 ...    9.
#      0.         1056.65744482]
#  [ 353.55487061  352.74462891  382.2517395  ...    8.
#      0.         2563.        ]
#  [ 387.48339844  385.38134766  376.66925049 ...   11.
#      0.          261.        ]]
# --------------
# (No. of tuples, No. of Columns before ReliefF) : (3539, 27)
# (No. of tuples , No. of Columns after ReliefF) : (3539, 15)

# %%
pd.options.display.max_columns = None
dataset.head(4)
# Out:
#         EV1  sol  sol_Hi  sol_Lo  sol_Mo  sol_VL         tot        lab  \
# 0 -0.015897  8.0       0       0     100       0  272.378723  19.742783
# 1 -0.009884  9.0       0      30      70       0  321.889160  39.771477
# 2 -0.009309  9.0       0      30      70       0  297.140411  15.604735
# 3 -0.010773  8.0       0       0     100       0  272.378723  19.742783
#
#           org         occ        sec        apa        stp10       stp100  \
# 0   67.555527  102.826088  30.978016  51.276287   794.583374   717.886108
# 1  130.869049   73.313477  23.083660  54.851479  1138.536743   981.948181
# 2   55.663460  130.878677  13.038733  81.954819  1196.093994  1057.599731
# 3   67.555527  102.826088  30.978016  51.276287   907.798584   800.458557
#
#          stp20        stp30    PBR1   PBR2    PHO1   PHO2   PMEH1  PMEH2  \
# 0   795.179993   761.795593   289.0   28.0   200.0    NaN   719.0  230.0
# 1  1075.211548   999.770813  1731.0    NaN     NaN    NaN     NaN    NaN
# 2  1163.314453  1074.673096  1817.0  181.0  2900.0  800.0  2521.0  306.0
# 3   843.005554   817.252258   533.0   14.0     NaN    NaN  1217.0  327.0
#
#      PNZ1    PNZ2   POL1   POL2    TP1    TP2    NPlim
# 0  4727.0  5387.0  650.0  199.0  700.0  600.0      NaN
# 1  3072.0  4551.0    NaN    NaN    NaN    NaN -0.47906
# 2  2258.0  2507.0  766.0  129.0  500.0  400.0 -0.46164
# 3  4256.0  4311.0  634.0    NaN  600.0  600.0      NaN

# %%
x_train = pd.DataFrame(X_train)
x_train.head(4)
# Out:
#             0            1            2            3          4           5   \
# 0   795.179993   761.795593   794.583374   717.886108  19.742783   67.555527
# 1  1075.211548   999.770813  1138.536743   981.948181  39.771477  130.869049
# 2  1163.314453  1074.673096  1196.093994  1057.599731  15.604735   55.663460
# 3   843.005554   817.252258   907.798584   800.458557  19.742783   67.555527
#
#            6          7          8           9      10    11   12   13      14
# 0  102.826088  30.978016  51.276287  272.378723  100.0   0.0  8.0  0.0   289.0
# 1   73.313477  23.083660  54.851479  321.889160   70.0  30.0  9.0  0.0  1731.0
# 2  130.878677  13.038733  81.954819  297.140411   70.0  30.0  9.0  0.0  1817.0
# 3  102.826088  30.978016  51.276287  272.378723  100.0   0.0  8.0  0.0   533.0
